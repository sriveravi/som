# %%
from minisom import MiniSom
import random as r
import copy as cop
import os
import numpy as np

from glob import glob
# import matplotlib as plt


# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
class SOM:
    def pertWeights( self, scale=.2 ):     
        print( 'Adding noise to SOM weights')
        pertAmount = scale*(np.random.random_sample( self.som.weights.shape)-.5)
        self.som.weights = self.som.weights + pertAmount
    
    def pertData( self, p=.2):
        print( 'Making %f percent of inputs 0.5' %(p*100))
        # randomly get proportion of indices to switch, then replace
        noiseIndex = np.random.binomial(1,p, self.data.shape)  #ones at p proportion of samples
        self.data[noiseIndex ==1 ] = .5
        return data
    
    # plot the thing
    def show( self):
        som = self.som
        data= self.data
        target = self.target
        bone()
        pcolor(som.distance_map().T) # plotting the distance map as background
        colorbar()
        t = zeros(len(target),dtype=int)
        t[target == 'A'] = 0
        t[target == 'B'] = 1
        # use different colors and markers for each label
        markers = ['o','s','D']
        colors = ['r','g','b']
        for cnt,xx in enumerate(self.data):
            w = som.winner(xx) # getting the winner
            # palce a marker on the winning position for the sample xx
            plot(w[0]+.5,w[1]+.5,markers[t[cnt]],markerfacecolor='None',
                markeredgecolor=colors[t[cnt]],markersize=12,markeredgewidth=2)
        axis([0,som.weights.shape[0],0,som.weights.shape[1]])
        show() # show the figure
    
    def train(self, iters = 30):
        self.som.train_random(self.data,iters)
        print( 'quantization error: %f' % self.som.quantization_error(self.data))
        
    #-------------------------------------------------
    
    def __init__(self, file_name='4750.csv', columns = [0,1,2,3,4,5,6,7], width = 7, height = 6 ):
        
        #       self.visual_only = [0,1,2,3,4,5,6,7]
        #       self.visual_and_acoustic = [0,1,2,3,4,5,6,7,8]

        # load data and normalization
        self.data = np.genfromtxt( file_name, delimiter=',',usecols=columns, skip_header=1)        
        self.data += -.5 
        # get target labels
        self.target = genfromtxt(file_name,delimiter=',',usecols=(9),dtype=str, skip_header=1) # loading the labels
        # init som
        self.som = MiniSom(width, height, self.data.shape[1], sigma=1.2,learning_rate=0.5)
        self.som.random_weights_init(self.data)

# %%
# how to use
mod = SOM('4750.csv')
mod.train(50)
mod.show()
# mod.train(5)
# mod.show()
# Out:
# quantization error: 0.456583

# %%
# loop through files and train up SOMs
fileDir = '../../KARS_reinf/Python/FeatSeenBySub/'
files= glob( fileDir+'*.csv')
for f in files:
    print( 'Participant %s:\n' % f.split('/')[-1] )
    mod = SOM( f)
    mod.train(50)
    mod.show()
# Out:
# Participant 4778.csv:
#
# quantization error: 0.432311
# Participant 4749.csv:
#
# quantization error: 0.371496
# Participant 4750.csv:
#
# quantization error: 0.452689
# Participant 4756.csv:
#
# quantization error: 0.359598
# Participant 4757.csv:
#
# quantization error: 0.360543
# Participant 4758.csv:
#
# quantization error: 0.320323
# Participant 4759.csv:
#
# quantization error: 0.252980
# Participant 4760.csv:
#
# quantization error: 0.292893
# Participant 4761.csv:
#
# quantization error: 0.398385
# Participant 4764.csv:
#
# quantization error: 0.357449
# Participant 4765.csv:
#
# quantization error: 0.344718
# Participant 4768.csv:
#
# quantization error: 0.411143
# Participant 4769.csv:
#
# quantization error: 0.224946
# Participant 4770.csv:
#
# quantization error: 0.344340
# Participant 4771.csv:
#
# quantization error: 0.334802
# Participant 4773.csv:
#
# quantization error: 0.384416
# Participant 4776.csv:
#
# quantization error: 0.392494
# Participant 4777.csv:
#
# quantization error: 0.403172
# Participant 4781.csv:
#
# quantization error: 0.281006
# Participant 4786.csv:
#
# quantization error: 0.287681
# Participant 4787.csv:
#
# quantization error: 0.431620
# Participant 4788.csv:
#
# quantization error: 0.329486
# Participant 4789.csv:
#
# quantization error: 0.447764
# Participant 4792.csv:
#
# quantization error: 0.349688
# Participant 4793.csv:
#
# quantization error: 0.419978
# Participant 4794.csv:
#
# quantization error: 0.364359
# Participant 4796.csv:
#
# quantization error: 0.386726
# Participant 4799.csv:
#
# quantization error: 0.350537
# Participant 4801.csv:
#
# quantization error: 0.322970
# Participant 4802.csv:
#
# quantization error: 0.320382
# Participant 4803.csv:
#
# quantization error: 0.366396
# Participant 4804.csv:
#
# quantization error: 0.294590
# Participant 4807.csv:
#
# quantization error: 0.333213
# Participant 4808.csv:
#
# quantization error: 0.491380
# Participant 4809.csv:
#
# quantization error: 0.351756

# %%
f
# Out:
# '../../KARS_reinf/Python/FeatSeenBySub/4809.csv'
